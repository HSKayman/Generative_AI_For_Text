# %%
import pandas as pd

# %%
def extract_info_from_file(file_path):
    data = {}

    with open(file_path, 'r') as file:
        for line in file:
            if not ":" in line:
                continue
            label, value = line.split(':', 1)
            if label in ["Epoch", "Loss", "Question", "Predicted Output"]:
                continue
            label = label.strip()
            value = value.strip()

            if len(value.split(" "))==2:
                if '.' in value:
                    value = float(value.split(" ")[0])
                else:
                    value = int(value.split(" ")[0]) 
            else:

                if '.' in value:
                    value = float(value)
                else:
                    value = int(value) 
            if label in data.keys():
                data[label].append(value)
            else:
                data[label]=[]

    return data

# %%
file_path = 'log.txt'

# %%
info = extract_info_from_file(file_path)

# %%
info
# Out:
# {'Number of elements': [100,
#   100,
#   100,
#   100,
#   100,
#   100,
#   100,
#   200,
#   200,
#   200,
#   200,
#   200,
#   200,
#   200,
#   200,
#   400,
#   400,
#   400,
#   400,
#   400,
#   400,
#   400,
#   400,
#   600,
#   600,
#   600,
#   600,
#   600,
#   600,
#   600,
#   600,
#   100,
#   100,
#   100,
#   100,
#   100,
#   100,
#   100,
#   100,
#   100,
#   100,
#   100,
#   100,
#   100,
#   100,
#   100,
#   100,
#   100,
#   100,
#   100,
#   100,
#   100,
#   100,
#   100,
#   100,
#   100,
#   100,
#   100,
#   100,
#   100,
#   100,
#   100,
#   100,
#   100,
#   100,
#   100,
#   100,
#   100,
#   100,
#   100,
#   100,
#   100,
#   100,
#   100,
#   100,
#   100,
#   200,
#   200,
#   200,
#   200,
#   200,
#   200,
#   200,
#   200,
#   200,
#   200,
#   200,
#   200,
#   200,
#   200,
#   200,
#   200,
#   200,
#   200,
#   200,
#   200,
#   200,
#   200,
#   200,
#   200,
#   200,
#   200,
#   200,
#   200,
#   200,
#   200,
#   200,
#   200,
#   200,
#   200,
#   200,
#   200,
#   200,
#   200,
#   200,
#   200,
#   200,
#   200,
#   200,
#   200,
#   200,
#   300,
#   300,
#   300,
#   300,
#   300,
#   300,
#   300,
#   300,
#   300,
#   300,
#   300,
#   300,
#   300,
#   300,
#   300,
#   300,
#   300,
#   300,
#   300,
#   300,
#   300,
#   300,
#   300,
#   300,
#   300,
#   300,
#   300,
#   300,
#   300,
#   300,
#   300,
#   300,
#   300,
#   300,
#   300,
#   300,
#   300,
#   300,
#   300,
#   300,
#   300,
#   300,
#   300,
#   300,
#   300,
#   400,
#   400,
#   400,
#   400,
#   400,
#   400,
#   400,
#   400,
#   400,
#   400,
#   400,
#   400,
#   400,
#   400,
#   400,
#   400,
#   400,
#   400,
#   400,
#   400,
#   400,
#   400,
#   400,
#   400,
#   400,
#   400,
#   400,
#   400,
#   400,
#   400,
#   400,
#   400,
#   400,
#   400,
#   400,
#   400,
#   400,
#   400,
#   400,
#   400,
#   400,
#   400,
#   400,
#   400,
#   400],
#  'Batch size': [16,
#   16,
#   16,
#   64,
#   64,
#   64,
#   64,
#   16,
#   16,
#   16,
#   16,
#   64,
#   64,
#   64,
#   64,
#   16,
#   16,
#   16,
#   16,
#   64,
#   64,
#   64,
#   64,
#   16,
#   16,
#   16,
#   16,
#   64,
#   64,
#   64,
#   64,
#   16,
#   16,
#   16,
#   16,
#   16,
#   16,
#   16,
#   16,
#   16,
#   16,
#   16,
#   16,
#   16,
#   16,
#   16,
#   32,
#   32,
#   32,
#   32,
#   32,
#   32,
#   32,
#   32,
#   32,
#   32,
#   32,
#   32,
#   32,
#   32,
#   32,
#   64,
#   64,
#   64,
#   64,
#   64,
#   64,
#   64,
#   64,
#   64,
#   64,
#   64,
#   64,
#   64,
#   64,
#   64,
#   16,
#   16,
#   16,
#   16,
#   16,
#   16,
#   16,
#   16,
#   16,
#   16,
#   16,
#   16,
#   16,
#   16,
#   16,
#   32,
#   32,
#   32,
#   32,
#   32,
#   32,
#   32,
#   32,
#   32,
#   32,
#   32,
#   32,
#   32,
#   32,
#   32,
#   64,
#   64,
#   64,
#   64,
#   64,
#   64,
#   64,
#   64,
#   64,
#   64,
#   64,
#   64,
#   64,
#   64,
#   64,
#   16,
#   16,
#   16,
#   16,
#   16,
#   16,
#   16,
#   16,
#   16,
#   16,
#   16,
#   16,
#   16,
#   16,
#   16,
#   32,
#   32,
#   32,
#   32,
#   32,
#   32,
#   32,
#   32,
#   32,
#   32,
#   32,
#   32,
#   32,
#   32,
#   32,
#   64,
#   64,
#   64,
#   64,
#   64,
#   64,
#   64,
#   64,
#   64,
#   64,
#   64,
#   64,
#   64,
#   64,
#   64,
#   16,
#   16,
#   16,
#   16,
#   16,
#   16,
#   16,
#   16,
#   16,
#   16,
#   16,
#   16,
#   16,
#   16,
#   16,
#   32,
#   32,
#   32,
#   32,
#   32,
#   32,
#   32,
#   32,
#   32,
#   32,
#   32,
#   32,
#   32,
#   32,
#   32,
#   64,
#   64,
#   64,
#   64,
#   64,
#   64,
#   64,
#   64,
#   64,
#   64,
#   64,
#   64,
#   64,
#   64,
#   64],
#  'Unit size': [256,
#   512,
#   512,
#   256,
#   256,
#   512,
#   512,
#   256,
#   256,
#   512,
#   512,
#   256,
#   256,
#   512,
#   512,
#   256,
#   256,
#   512,
#   512,
#   256,
#   256,
#   512,
#   512,
#   256,
#   256,
#   512,
#   512,
#   256,
#   256,
#   512,
#   512,
#   128,
#   128,
#   128,
#   128,
#   128,
#   256,
#   256,
#   256,
#   256,
#   256,
#   512,
#   512,
#   512,
#   512,
#   512,
#   128,
#   128,
#   128,
#   128,
#   128,
#   256,
#   256,
#   256,
#   256,
#   256,
#   512,
#   512,
#   512,
#   512,
#   512,
#   128,
#   128,
#   128,
#   128,
#   128,
#   256,
#   256,
#   256,
#   256,
#   256,
#   512,
#   512,
#   512,
#   512,
#   512,
#   128,
#   128,
#   128,
#   128,
#   128,
#   256,
#   256,
#   256,
#   256,
#   256,
#   512,
#   512,
#   512,
#   512,
#   512,
#   128,
#   128,
#   128,
#   128,
#   128,
#   256,
#   256,
#   256,
#   256,
#   256,
#   512,
#   512,
#   512,
#   512,
#   512,
#   128,
#   128,
#   128,
#   128,
#   128,
#   256,
#   256,
#   256,
#   256,
#   256,
#   512,
#   512,
#   512,
#   512,
#   512,
#   128,
#   128,
#   128,
#   128,
#   128,
#   256,
#   256,
#   256,
#   256,
#   256,
#   512,
#   512,
#   512,
#   512,
#   512,
#   128,
#   128,
#   128,
#   128,
#   128,
#   256,
#   256,
#   256,
#   256,
#   256,
#   512,
#   512,
#   512,
#   512,
#   512,
#   128,
#   128,
#   128,
#   128,
#   128,
#   256,
#   256,
#   256,
#   256,
#   256,
#   512,
#   512,
#   512,
#   512,
#   512,
#   128,
#   128,
#   128,
#   128,
#   128,
#   256,
#   256,
#   256,
#   256,
#   256,
#   512,
#   512,
#   512,
#   512,
#   512,
#   128,
#   128,
#   128,
#   128,
#   128,
#   256,
#   256,
#   256,
#   256,
#   256,
#   512,
#   512,
#   512,
#   512,
#   512,
#   128,
#   128,
#   128,
#   128,
#   128,
#   256,
#   256,
#   256,
#   256,
#   256,
#   512,
#   512,
#   512,
#   512,
#   512],
#  'Number of epochs': [300,
#   100,
#   300,
#   100,
#   300,
#   100,
#   300,
#   100,
#   300,
#   100,
#   300,
#   100,
#   300,
#   100,
#   300,
#   100,
#   300,
#   100,
#   300,
#   100,
#   300,
#   100,
#   300,
#   100,
#   300,
#   100,
#   300,
#   100,
#   300,
#   100,
#   300,
#   100,
#   200,
#   300,
#   400,
#   500,
#   100,
#   200,
#   300,
#   400,
#   500,
#   100,
#   200,
#   300,
#   400,
#   500,
#   100,
#   200,
#   300,
#   400,
#   500,
#   100,
#   200,
#   300,
#   400,
#   500,
#   100,
#   200,
#   300,
#   400,
#   500,
#   100,
#   200,
#   300,
#   400,
#   500,
#   100,
#   200,
#   300,
#   400,
#   500,
#   100,
#   200,
#   300,
#   400,
#   500,
#   100,
#   200,
#   300,
#   400,
#   500,
#   100,
#   200,
#   300,
#   400,
#   500,
#   100,
#   200,
#   300,
#   400,
#   500,
#   100,
#   200,
#   300,
#   400,
#   500,
#   100,
#   200,
#   300,
#   400,
#   500,
#   100,
#   200,
#   300,
#   400,
#   500,
#   100,
#   200,
#   300,
#   400,
#   500,
#   100,
#   200,
#   300,
#   400,
#   500,
#   100,
#   200,
#   300,
#   400,
#   500,
#   100,
#   200,
#   300,
#   400,
#   500,
#   100,
#   200,
#   300,
#   400,
#   500,
#   100,
#   200,
#   300,
#   400,
#   500,
#   100,
#   200,
#   300,
#   400,
#   500,
#   100,
#   200,
#   300,
#   400,
#   500,
#   100,
#   200,
#   300,
#   400,
#   500,
#   100,
#   200,
#   300,
#   400,
#   500,
#   100,
#   200,
#   300,
#   400,
#   500,
#   100,
#   200,
#   300,
#   400,
#   500,
#   100,
#   200,
#   300,
#   400,
#   500,
#   100,
#   200,
#   300,
#   400,
#   500,
#   100,
#   200,
#   300,
#   400,
#   500,
#   100,
#   200,
#   300,
#   400,
#   500,
#   100,
#   200,
#   300,
#   400,
#   500,
#   100,
#   200,
#   300,
#   400,
#   500,
#   100,
#   200,
#   300,
#   400,
#   500,
#   100,
#   200,
#   300,
#   400,
#   500,
#   100,
#   200,
#   300,
#   400,
#   500],
#  'Duration': [65.2991,
#   27.893,
#   85.2397,
#   6.6253,
#   19.3441,
#   8.2763,
#   25.1843,
#   50.5211,
#   149.4335,
#   58.8203,
#   181.0379,
#   14.6104,
#   43.6614,
#   19.3923,
#   60.86,
#   117.9139,
#   341.1555,
#   138.3191,
#   406.2094,
#   42.4684,
#   120.3792,
#   51.09,
#   150.4429,
#   178.7883,
#   531.3634,
#   208.358,
#   625.3431,
#   65.4947,
#   197.2308,
#   77.3129,
#   234.3337,
#   19.8783,
#   39.1006,
#   59.0527,
#   81.1058,
#   99.0905,
#   21.2521,
#   42.4735,
#   65.2739,
#   89.4192,
#   111.3385,
#   28.2024,
#   56.3019,
#   84.7964,
#   111.74,
#   134.2353,
#   8.9642,
#   17.6298,
#   26.5343,
#   35.1514,
#   44.6052,
#   9.6831,
#   19.4734,
#   28.5824,
#   39.4642,
#   48.968,
#   12.4708,
#   24.703,
#   36.923,
#   50.2395,
#   64.0799,
#   5.5754,
#   11.0887,
#   16.5684,
#   22.054,
#   27.1014,
#   6.1599,
#   12.4148,
#   18.4044,
#   24.2775,
#   31.292,
#   8.545,
#   16.7507,
#   25.0427,
#   33.1421,
#   41.0589,
#   42.8808,
#   89.2909,
#   134.5097,
#   187.5605,
#   229.372,
#   49.4628,
#   103.3988,
#   149.3513,
#   204.9566,
#   253.5953,
#   63.3467,
#   122.8907,
#   184.8234,
#   242.6242,
#   306.4517,
#   26.7922,
#   57.6005,
#   83.2299,
#   109.3014,
#   138.8238,
#   29.794,
#   61.1255,
#   94.5774,
#   119.7677,
#   154.1461,
#   38.4908,
#   78.7682,
#   118.2473,
#   156.5069,
#   190.0281,
#   14.1427,
#   27.3546,
#   40.5879,
#   52.6398,
#   67.5843,
#   16.1065,
#   29.8143,
#   44.4861,
#   58.0309,
#   74.9701,
#   21.0448,
#   41.1872,
#   59.8389,
#   77.6901,
#   99.6336,
#   69.3945,
#   143.1879,
#   213.4153,
#   286.7649,
#   353.0791,
#   80.17,
#   155.4665,
#   238.6518,
#   320.6282,
#   396.1997,
#   97.5728,
#   188.451,
#   287.012,
#   379.2474,
#   477.413,
#   42.1098,
#   83.8583,
#   120.2018,
#   165.2027,
#   209.3696,
#   46.7273,
#   94.2223,
#   139.8711,
#   182.7469,
#   234.1435,
#   56.7976,
#   115.2642,
#   171.8986,
#   230.5006,
#   283.796,
#   20.8488,
#   40.2533,
#   59.463,
#   86.9109,
#   102.3044,
#   23.6151,
#   48.9809,
#   73.0965,
#   93.7689,
#   122.5057,
#   30.8933,
#   59.5865,
#   90.4107,
#   121.9548,
#   155.0778,
#   104.019,
#   213.3964,
#   317.9254,
#   425.0877,
#   533.9136,
#   118.0928,
#   234.0925,
#   349.7589,
#   466.2501,
#   587.5394,
#   138.4849,
#   280.7106,
#   418.4246,
#   560.5042,
#   701.2358,
#   61.4541,
#   124.0037,
#   177.1895,
#   246.0669,
#   310.9263,
#   68.6614,
#   137.3514,
#   196.3261,
#   276.4767,
#   343.2099,
#   83.0769,
#   170.7859,
#   247.3495,
#   339.7329,
#   420.4839,
#   38.7407,
#   75.0989,
#   101.7187,
#   144.9233,
#   180.8624,
#   43.0575,
#   80.9796,
#   125.7988,
#   164.5011,
#   209.0276,
#   50.9966,
#   101.1685,
#   155.0721,
#   206.2048,
#   253.2812]}

# %%
df = pd.DataFrame(info)

# %%
df
# Out:
#      Number of elements  Batch size  Unit size  Number of epochs  Duration
# 0                   100          16        256               300   65.2991
# 1                   100          16        512               100   27.8930
# 2                   100          16        512               300   85.2397
# 3                   100          64        256               100    6.6253
# 4                   100          64        256               300   19.3441
# ..                  ...         ...        ...               ...       ...
# 206                 400          64        512               100   50.9966
# 207                 400          64        512               200  101.1685
# 208                 400          64        512               300  155.0721
# 209                 400          64        512               400  206.2048
# 210                 400          64        512               500  253.2812
#
# [211 rows x 5 columns]

# %%
df.to_csv(file_path[:-3]+"csv")
